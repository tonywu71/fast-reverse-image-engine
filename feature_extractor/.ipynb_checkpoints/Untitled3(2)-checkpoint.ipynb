# %%
#!pip install --ignore-installed --upgrade keras

# %%
if False:
  # !echo "Downloading Data Base"
  # !wget https://navee-public.s3-eu-west-1.amazonaws.com/20170509-bam-2.2m-Nja9G.sqlite.bz2
  # !bzip2 -d 20170509-bam-2.2m-Nja9G.sqlite.bz2
  # !mv 20170509-bam-2.2m-Nja9G.sqlite data.sqlite

# %%
classes = {0: 'content_building', 1:'emotion_happy', 2:'content_flower',
                    3:'content_bicycle', 4:'media_comic', 5:'content_people',
                    6:'media_3d_graph',7:'content_dog',8:'media_vectorart',9:'emotion_scary',
                    10:'emotion_gloom', 11: 'media_graphite', 12: 'emotion_peaceful', 13: 'media_pen_ink',
                    14:'content_cars', 15:'media_oilpaint', 16: 'content_cat', 17: 'content_tree', 18: 'content_bird',19:'media_watercolor'}
list_classes = [classes[i] for i in range(20)]
list_content = []
list_emotion = []
list_media = []
for i in list_classes:
  if(i[:7] == 'content'):
    list_content.append(i)
  elif(i[:7] == 'emotion'):
    list_emotion.append(i)
  else:
    list_media.append(i)

print(list_content)

def return_class(res):
  cls = []
  for i in range(len(res)):
    if(res[i]>0.55):
      cls.append(classes[i])
  
  return cls
# Out:
# ['content_building', 'content_flower', 'content_bicycle', 'content_people', 'content_dog', 'content_cars', 'content_cat', 'content_tree', 'content_bird']

# %%
import numpy as np
from Data_Gen import DataGenerator
from data import *

# %%
import matplotlib.pyplot as plt
from keras.regularizers import l2
# Out:
# Using TensorFlow backend.

# %% [markdown]
# <h1>Creating the Keras model:<h1/>

# %% [markdown]
# **Importing the modules needed**

# %%
from keras.applications.resnet import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.models import Model, Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D
from keras.layers import Dropout, Flatten, GlobalAveragePooling2D, BatchNormalization

# %%
model = Sequential()
model.add(ResNet50(include_top = False,weights = 'imagenet'))
model.add(Dropout(0.2))
model.add(Conv2D(4096,3,activation='relu'))
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.5))
model.add(Dense(5000,activation='relu',kernel_regularizer= l2(0.1), bias_regularizer=l2(0.1)))
model.add(Dense(3000))
model.add(Dense(2048))
model.add(Dense(1024))
model.add(Dense(20,activation = 'sigmoid'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, None, None, 2048)  23587712
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, None, 2048)  0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 4096)  75501568
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, None, 4096)  16384
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 4096)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5000)              20485000
# _________________________________________________________________
# dense_2 (Dense)              (None, 3000)              15003000
# _________________________________________________________________
# dense_3 (Dense)              (None, 2048)              6146048
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                20500
# =================================================================
# Total params: 142,858,388
# Trainable params: 142,797,076
# Non-trainable params: 61,312
# _________________________________________________________________

# %%
#model.layers[0].summary()

# %%
model.layers[0].trainable = True
for i in model.layers[0].layers:
  i.trainable = False

for i in range(4):
  model.layers[0].layers[-i].trainable = True

model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %% [markdown]
# <h1>Loading dataset<h1/>

# %% [markdown]
# **In here the module data and Data_Gen created will be used to help loading the model**

# %% [markdown]
# 1. First we will create a function that take a PIL.Image object and convert to a vector of shape (224,224,3) and preprocess to use in ResNet

# %%
def preprocess(x):
    x = x.convert('RGB')
    x = x.resize((224,224))
    x = np.array(x)
    return preprocess_input(x)

# %% [markdown]
# 2. Now we are going to take the Images ID's that are going to be used to train and test the model

# %%
ptest = 0.3

# %%
db = data_base()
# Datasets
IDs = db.get_images(1000)
labels = {i:db.get_label(i) for i in IDs}

# %%
dados = {}
for i in ['media', 'content', 'emotions']:
  dados[i] = []

# %%
partition = {}
partition['train'] = IDs[:int((1-ptest)*len(IDs))]
partition['test'] = IDs[int((1-ptest)*len(IDs)):len(IDs)]

print(len(partition['test'])/len(IDs))
# Out:
# 0.3002022536839064

# %% [markdown]
# 3. Creating Generator to make for efficient memory use ( It is a array that loads the data only when there's a request for the data )

# %%
train_generator = DataGenerator(partition['train'], labels,db=db, pre = preprocess,n_classes=4)
validation_generator = DataGenerator(partition['test'], labels, db = db,pre = preprocess)

# %%
proportion = {classes[i]:0 for i in classes}
for i in labels.keys():
  for j in return_class(labels[i]):
    proportion[j] = proportion[j]+1

for i in proportion:
  print(i, ": ",proportion[i]/len(labels)*100,"%")
# Out:
# content_building :  5.894250216700376 %
# emotion_happy :  5.923143600115574 %
# content_flower :  5.778676683039584 %
# content_bicycle :  5.778676683039584 %
# media_comic :  9.303669459693731 %
# content_people :  21.467783877492057 %
# media_3d_graph :  5.865356833285178 %
# content_dog :  5.778676683039584 %
# media_vectorart :  5.807570066454782 %
# emotion_scary :  5.778676683039584 %
# emotion_gloom :  6.154290667437157 %
# media_graphite :  5.865356833285178 %
# emotion_peaceful :  7.801213522103438 %
# media_pen_ink :  6.038717133776365 %
# content_cars :  6.645478185495522 %
# media_oilpaint :  5.778676683039584 %
# content_cat :  5.778676683039584 %
# content_tree :  6.356544351343542 %
# content_bird :  5.807570066454782 %
# media_watercolor :  5.83646344986998 %

# %% [markdown]
# 4. Showing the format of some images and how the generator works

# %%
a = train_generator[3][0]

# %%
def show_im(a):
  plt.imshow(a/255)
  plt.show()
show_im(a[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# 5. Making a prediction with some images (OBS the model is not trained yet, it's just to understand how it will work)

# %%
res = model.predict(a)

# %%
res[0]
# Out:
# array([0.7558561 , 0.24199705, 0.19826321, 0.18778193, 0.65393287,
#        0.3577549 , 0.8059352 , 0.40185103, 0.09038189, 0.7810026 ,
#        0.53185797, 0.46107578, 0.7066612 , 0.6608523 , 0.11023161,
#        0.74204755, 0.22839993, 0.67191976, 0.27979928, 0.40524378],
#       dtype=float32)

# %% [markdown]
# <h1>Training the Model<h1/>

# %%
#model.load_weights('weights2.h5')
#train_generator[0][0][2] = train_generator[0][0][0]
#train_generator[0][0][3] = train_generator[0][0][10]

# %%
model.fit_generator(train_generator,steps_per_epoch=train_generator.__len__(),
                          validation_data = validation_generator,
                          validation_steps = validation_generator.__len__(), epochs=10, verbose=True, shuffle=True)
# Out:
# Epoch 1/10
# 53/75 [====================>.........] - ETA: 4:13 - loss: 71.3080 - accuracy: 0.8560
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# 75/75 [==============================] - 1116s 15s/step - loss: 50.6935 - accuracy: 0.8784 - val_loss: 0.7880 - val_accuracy: 0.9330
# Epoch 2/10
# 75/75 [==============================] - 297s 4s/step - loss: 0.3894 - accuracy: 0.9438 - val_loss: 0.5499 - val_accuracy: 0.9209
# Epoch 3/10
# 75/75 [==============================] - 265s 4s/step - loss: 0.3995 - accuracy: 0.9437 - val_loss: 0.5668 - val_accuracy: 0.9250
# Epoch 4/10
# 75/75 [==============================] - 258s 3s/step - loss: 0.3923 - accuracy: 0.9478 - val_loss: 0.5540 - val_accuracy: 0.9178
# Epoch 5/10
# 75/75 [==============================] - 255s 3s/step - loss: 0.3976 - accuracy: 0.9498 - val_loss: 0.5321 - val_accuracy: 0.9230
# Epoch 6/10
# 75/75 [==============================] - 250s 3s/step - loss: 0.3967 - accuracy: 0.9531 - val_loss: 0.5197 - val_accuracy: 0.9214
# Epoch 7/10
# 75/75 [==============================] - 256s 3s/step - loss: 0.3997 - accuracy: 0.9525 - val_loss: 0.5159 - val_accuracy: 0.9263
# Epoch 8/10
# 75/75 [==============================] - 257s 3s/step - loss: 0.3670 - accuracy: 0.9579 - val_loss: 0.5499 - val_accuracy: 0.9207
# Epoch 9/10
# 75/75 [==============================] - 249s 3s/step - loss: 0.3568 - accuracy: 0.9589 - val_loss: 0.5432 - val_accuracy: 0.9232
# Epoch 10/10
# 75/75 [==============================] - 251s 3s/step - loss: 0.3279 - accuracy: 0.9619 - val_loss: 0.4988 - val_accuracy: 0.9252

# %%
i = 9
j=1
url = 'https://media2.carredartistes.com/us/17934-thickbox_default/unique-contemporary-artwork-agusil-happy.jpg'
img = load_image(url=url)
b = preprocess(img)
a = np.expand_dims(b,axis=0)
#a = np.expand_dims(validation_generator[j][0][i],axis=0)
#b = validation_generator[j][0][i]
#certo = validation_generator[j][1][i]

# %%
res = model.predict(a)
show_im(b)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print(res)
return_class(res[0])
# Out:
# [[0.00359024 0.05815772 0.00654678 0.00342193 0.0185244  0.0232931
#   0.0493684  0.02046078 0.00207772 0.9067898  0.00769233 0.00224841
#   0.00488732 0.00474275 0.00210508 0.00352467 0.00223449 0.0012253
#   0.06732474 0.01804562]]
# ['emotion_scary']

# %%
return_class(certo)
# Out:
# ['content_cars']

# %%
#model.save('model')

# %%
model.save_weights('weights_certo.h5')

# %%
for i in train_generator[0][0]:
  print(i.shape)
  plt.imshow(i)
  plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)

# %%
train_generator[0][0][2]
# Out:
# array([[[-76.93900299, -74.77899933, -73.68000031],
#         [-84.93900299, -77.77899933, -80.68000031],
#         [-82.93900299, -77.77899933, -79.68000031],
#         ...,
#         [ 40.06099701,  11.22100067, -13.68000031],
#         [ 36.06099701,  24.22100067,  -0.68000031],
#         [ 53.06099701,  42.22100067,  16.31999969]],
#
#        [[-80.93900299, -77.77899933, -79.68000031],
#         [-81.93900299, -77.77899933, -77.68000031],
#         [-84.93900299, -78.77899933, -77.68000031],
#         ...,
#         [ 99.06099701,  72.22100067,  45.31999969],
#         [ 94.06099701,  79.22100067,  49.31999969],
#         [ 57.06099701,  41.22100067,  14.31999969]],
#
#        [[-75.93900299, -69.77899933, -71.68000031],
#         [-96.93900299, -94.77899933, -92.68000031],
#         [-92.93900299, -90.77899933, -87.68000031],
#         ...,
#         [131.06100464, 119.22100067, 103.31999969],
#         [126.06099701, 113.22100067,  94.31999969],
#         [ 77.06099701,  61.22100067,  27.31999969]],
#
#        ...,
#
#        [[-22.93900299,   3.22100067,  17.31999969],
#         [-73.93900299, -37.77899933,  -7.68000031],
#         [-79.93900299, -53.77899933, -24.68000031],
#         ...,
#         [-75.93900299, -65.77899933, -67.68000031],
#         [-77.93900299, -63.77899933, -66.68000031],
#         [-70.93900299, -52.77899933, -57.68000031]],
#
#        [[-28.93900299, -19.77899933,  -5.68000031],
#         [-86.93900299, -71.77899933, -45.68000031],
#         [-86.93900299, -73.77899933, -50.68000031],
#         ...,
#         [-75.93900299, -60.77899933, -57.68000031],
#         [-74.93900299, -57.77899933, -56.68000031],
#         [-65.93900299, -47.77899933, -48.68000031]],
#
#        [[-24.93900299, -11.77899933,   4.31999969],
#         [-71.93900299, -56.77899933, -29.68000031],
#         [-70.93900299, -52.77899933, -23.68000031],
#         ...,
#         [-71.93900299, -54.77899933, -47.68000031],
#         [-71.93900299, -53.77899933, -49.68000031],
#         [-62.93900299, -43.77899933, -43.68000031]]])
