# %%
import numpy as np
from Data_Gen import DataGenerator
from data import *
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>Creating the Keras model:<h1/>

# %% [markdown]
# **Importing the modules needed**

# %%
from keras.applications.resnet import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.models import Model, Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D
from keras.layers import Dropout, Flatten, GlobalAveragePooling2D

# %%
model = Sequential()
model.add(ResNet50(include_top = False,weights = 'imagenet'))
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.4))
model.add(Dense(512,activation='relu'))
model.add(Dense(20,activation = 'sigmoid'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, None, None, 2048)  23587712
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                10260
# =================================================================
# Total params: 24,647,060
# Trainable params: 24,593,940
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
model.layers[0].trainable = False
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %% [markdown]
# <h1>Loading dataset<h1/>

# %% [markdown]
# **In here the module data and Data_Gen created will be used to help loading the model**

# %% [markdown]
# 1. First we will create a function that take a PIL.Image object and convert to a vector of shape (224,224,3) and preprocess to use in ResNet

# %%
def preprocess(x):
    x = x.convert('RGB')
    x = x.resize((224,224))
    x = np.array(x)
    return preprocess_input(x)

# %% [markdown]
# 2. Now we are going to take the Images ID's that are going to be used to train and test the model

# %%
ptest = 0.3

# %%
db = data_base()
# Datasets
IDs = db.get_images(100)
labels = {i:db.get_label(i) for i in IDs}

# %%
partition = {}
partition['train'] = IDs[:int((1-ptest)*len(IDs))]
partition['test'] = IDs[int((1-ptest)*len(IDs)):len(IDs)]

print(len(partition['test'])/len(IDs))
# Out:
# 0.3

# %% [markdown]
# 3. Creating Generator to make for efficient memory use ( It is a array that loads the data only when there's a request for the data )

# %%
train_generator = DataGenerator(partition['train'], labels,db=db, pre = preprocess)
validation_generator = DataGenerator(partition['test'], labels, db = db,pre = preprocess)

# %% [markdown]
# 4. Showing the format of some images and how the generator works

# %%
a = train_generator[0][0]

# %%
plt.imshow(a[8]/255)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# 5. Making a prediction with some images (OBS the model is not trained yet, it's just to understand how it will work)

# %%
res = model.predict(a)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.4/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
res[0]
# Out:
# array([0.2901241 , 0.2678582 , 0.5200837 , 0.8641759 , 0.29645613,
#        0.39536783, 0.71912384, 0.34388536, 0.15515041, 0.5452338 ,
#        0.7795266 , 0.36832124, 0.23375866, 0.7293046 , 0.2929888 ,
#        0.3394266 , 0.13394311, 0.20805022, 0.07776928, 0.56798166],
#       dtype=float32)

# %% [markdown]
# <h1>Training the Model<h1/>

# %%
model.fit_generator(train_generator,steps_per_epoch=train_generator.__len__(),
                          validation_data = validation_generator,
                          validation_steps = validation_generator.__len__(), epochs=10, verbose=True, shuffle=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.4/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/10
#  12/218 [>.............................] - ETA: 1:27:54 - loss: 11.4097 - accuracy: 0.0208
# /usr/lib/python3/dist-packages/PIL/Image.py:857: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
#  23/218 [==>...........................] - ETA: 1:19:21 - loss: 11.0611 - accuracy: 0.0272
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/urllib3/response.py in _error_catcher(self)
#     361             try:
# --> 362                 yield
#     363
#
# /usr/local/lib/python3.4/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     443                 cache_content = False
# --> 444                 data = self._fp.read(amt)
#     445                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# /usr/lib/python3.4/http/client.py in read(self, amt)
#     538             # (which is implemented in terms of self.readinto)
# --> 539             return super(HTTPResponse, self).read(amt)
#     540         else:
#
# /usr/lib/python3.4/http/client.py in readinto(self, b)
#     577         # (for example, reading in 1k chunks)
# --> 578         n = self.fp.readinto(b)
#     579         if not n and b:
#
# /usr/lib/python3.4/socket.py in readinto(self, b)
#     370             try:
# --> 371                 return self._sock.recv_into(b)
#     372             except timeout:
#
# /usr/lib/python3.4/ssl.py in recv_into(self, buffer, nbytes, flags)
#     744                   self.__class__)
# --> 745             return self.read(nbytes, buffer)
#     746         else:
#
# /usr/lib/python3.4/ssl.py in read(self, len, buffer)
#     616             if buffer is not None:
# --> 617                 v = self._sslobj.read(len, buffer)
#     618             else:
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/requests/models.py in generate()
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#
# /usr/local/lib/python3.4/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     495             while not is_fp_closed(self._fp):
# --> 496                 data = self.read(amt=amt, decode_content=decode_content)
#     497
#
# /usr/local/lib/python3.4/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     460                         # Content-Length are caught.
# --> 461                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     462
#
# /usr/lib/python3.4/contextlib.py in __exit__(self, type, value, traceback)
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#
# /usr/local/lib/python3.4/dist-packages/urllib3/response.py in _error_catcher(self)
#     379                 # This includes IncompleteRead.
# --> 380                 raise ProtocolError('Connection broken: %r' % e, e)
#     381
#
# ProtocolError: ("Connection broken: ConnectionResetError(104, 'Connection reset by peer')", ConnectionResetError(104, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# <ipython-input-43-7c132ec3b427> in <module>()
#       1 model.fit_generator(train_generator,steps_per_epoch=train_generator.__len__(),
#       2                           validation_data = validation_generator,
# ----> 3                           validation_steps = validation_generator.__len__(), epochs=10, verbose=True, shuffle=True)
#
# /usr/local/lib/python3.4/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.4/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.4/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     183             batch_index = 0
#     184             while steps_done < steps_per_epoch:
# --> 185                 generator_output = next(output_generator)
#     186
#     187                 if not hasattr(generator_output, '__len__'):
#
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py in get(self)
#     623         except Exception:
#     624             self.stop()
# --> 625             six.reraise(*sys.exc_info())
#     626
#     627
#
# /usr/local/lib/python3.4/dist-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py in get(self)
#     608                 try:
#     609                     future = self.queue.get(block=True)
# --> 610                     inputs = future.get(timeout=30)
#     611                 except mp.TimeoutError:
#     612                     idx = future.idx
#
# /usr/lib/python3.4/multiprocessing/pool.py in get(self, timeout)
#     597             return self._value
#     598         else:
# --> 599             raise self._value
#     600
#     601     def _set(self, i, obj):
#
# /usr/lib/python3.4/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception:
#
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py in get_index(uid, i)
#     404         The value at index `i`.
#     405     """
# --> 406     return _SHARED_SEQUENCES[uid][i]
#     407
#     408
#
# /home/matheus/Documentos/CentraleSupelec/Pole Projet/Arts/Data/Data_Gen.py in __getitem__(self, index)
#      33
#      34         # Generate data
# ---> 35         X, y = self.__data_generation(list_IDs_temp)
#      36
#      37         return X, y
#
# /home/matheus/Documentos/CentraleSupelec/Pole Projet/Arts/Data/Data_Gen.py in __data_generation(self, list_IDs_temp)
#      55             #X[i,] = np.load('data/' + ID + '.npy')
#      56             image_url = self.db.get_image(ID)
# ---> 57             image = load_image(image_url)
#      58             X[i,] = self.pre(image)
#      59
#
# /home/matheus/Documentos/CentraleSupelec/Pole Projet/Arts/Data/data.py in load_image(url)
#      11
#      12 def load_image(url):
# ---> 13     reponse = requests.get(url)
#      14     img = Image.open(bio(reponse.content))
#      15     return img
#
# /usr/local/lib/python3.4/dist-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/lib/python3.4/dist-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /usr/local/lib/python3.4/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/local/lib/python3.4/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# /usr/local/lib/python3.4/dist-packages/requests/models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# /usr/local/lib/python3.4/dist-packages/requests/models.py in generate()
#     751                         yield chunk
#     752                 except ProtocolError as e:
# --> 753                     raise ChunkedEncodingError(e)
#     754                 except DecodeError as e:
#     755                     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ("Connection broken: ConnectionResetError(104, 'Connection reset by peer')", ConnectionResetError(104, 'Connection reset by peer'))
