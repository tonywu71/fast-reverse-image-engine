# %%
if False:
  # !echo "Downloading Data Base"
  # !wget https://navee-public.s3-eu-west-1.amazonaws.com/20170509-bam-2.2m-Nja9G.sqlite.bz2
  # !bzip2 -d 20170509-bam-2.2m-Nja9G.sqlite.bz2
  # !mv 20170509-bam-2.2m-Nja9G.sqlite data.sqlite

# %%
classes = {0: 'content_building', 1:'emotion_happy', 2:'content_flower',
                    3:'content_bicycle', 4:'media_comic', 5:'content_people',
                    6:'media_3d_graph',7:'content_dog',8:'media_vectorart',9:'emotion_scary',
                    10:'emotion_gloom', 11: 'media_graphite', 12: 'emotion_peaceful', 13: 'media_pen_ink',
                    14:'content_cars', 15:'media_oilpaint', 16: 'content_cat', 17: 'content_tree', 18: 'content_bird',19:'media_watercolor'}

classes = {0:'emotion_happy',1:'emotion_scary',2:'emotion_gloom',3: 'emotion_peaceful'}

def return_class(res):
  cls = []
  for i in range(len(res)):
    if(res[i]>0.55):
      cls.append(classes[i])
  
  return cls

# %%
import numpy as np
from Data_Gen import DataGenerator
from data import *
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt
from keras.regularizers import l2

# %% [markdown]
# <h1>Creating the Keras model:<h1/>

# %% [markdown]
# **Importing the modules needed**

# %%
from keras.applications.resnet import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.models import Model, Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D
from keras.layers import Dropout, Flatten, GlobalAveragePooling2D

# %%
model = Sequential()
model.add(ResNet50(include_top = False,weights = 'imagenet'))
model.add(Dropout(0.2))
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.5))
model.add(Dense(32*4,activation='relu',kernel_regularizer= l2(0.1), bias_regularizer=l2(0.1)))
model.add(Dense(4,activation = 'sigmoid'))
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.4/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, None, None, 2048)  23587712
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, None, 2048)  0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               262272
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 23,850,500
# Trainable params: 23,797,380
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
model.layers[0].trainable = True
for i in model.layers[0].layers:
  i.trainable = False

for i in range(4):
  model.layers[0].layers[-i].trainable = True

model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.4/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# <h1>Loading dataset<h1/>

# %% [markdown]
# **In here the module data and Data_Gen created will be used to help loading the model**

# %% [markdown]
# 1. First we will create a function that take a PIL.Image object and convert to a vector of shape (224,224,3) and preprocess to use in ResNet

# %%
def preprocess(x):
    x = x.convert('RGB')
    x = x.resize((224,224))
    x = np.array(x)
    return preprocess_input(x)

# %% [markdown]
# 2. Now we are going to take the Images ID's that are going to be used to train and test the model

# %%
ptest = 0.3

# %%
db = data_base()
# Datasets
IDs = db.get_images_emotions(5000)
labels = {i:db.get_label_emotions(i) for i in IDs}

# %%
partition = {}
partition['train'] = IDs[:int((1-ptest)*len(IDs))]
partition['test'] = IDs[int((1-ptest)*len(IDs)):len(IDs)]

print(len(partition['test'])/len(IDs))
# Out:
# 0.3

# %% [markdown]
# 3. Creating Generator to make for efficient memory use ( It is a array that loads the data only when there's a request for the data )

# %%
train_generator = DataGenerator(partition['train'], labels,db=db, pre = preprocess,n_classes=4)
validation_generator = DataGenerator(partition['test'], labels, db = db,pre = preprocess)

# %% [markdown]
# 4. Showing the format of some images and how the generator works

# %%
a = train_generator[3][0]

# %%
def show_im(a):
  plt.imshow(a/255)
  plt.show()
show_im(a[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# 5. Making a prediction with some images (OBS the model is not trained yet, it's just to understand how it will work)

# %%
res = model.predict(a)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.4/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
res[0]
# Out:
# array([0.3153292 , 0.46248883, 0.37997067, 0.82737964], dtype=float32)

# %% [markdown]
# <h1>Training the Model<h1/>

# %%
#model.load_weights('weights2_emotions.h5')
#train_generator[0][0][2] = train_generator[0][0][0]
#train_generator[0][0][3] = train_generator[0][0][10]

# %%
model.fit_generator(train_generator,steps_per_epoch=train_generator.__len__(),
                          validation_data = validation_generator,
                          validation_steps = validation_generator.__len__(), epochs=30, verbose=True, shuffle=True)
# Out:
# Epoch 1/30
# 109/109 [==============================] - 2413s 22s/step - loss: 0.4023 - accuracy: 0.8971 - val_loss: 0.3962 - val_accuracy: 0.9100
# Epoch 2/30
# 109/109 [==============================] - 2076s 19s/step - loss: 0.4269 - accuracy: 0.8918 - val_loss: 0.3568 - val_accuracy: 0.9006
# Epoch 3/30
# 109/109 [==============================] - 2085s 19s/step - loss: 0.4017 - accuracy: 0.8951 - val_loss: 0.4190 - val_accuracy: 0.9098
# Epoch 4/30
#  97/109 [=========================>....] - ETA: 4:18 - loss: 0.4191 - accuracy: 0.8905
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 5 could not be retrieved. It could be because a worker has died.
#   UserWarning)
#  98/109 [=========================>....] - ETA: 4:01 - loss: 0.4190 - accuracy: 0.8905
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 94 could not be retrieved. It could be because a worker has died.
#   UserWarning)
#  99/109 [==========================>...] - ETA: 3:43 - loss: 0.4190 - accuracy: 0.8909
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 69 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 100/109 [==========================>...] - ETA: 3:23 - loss: 0.4190 - accuracy: 0.8909
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 89 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 101/109 [==========================>...] - ETA: 3:03 - loss: 0.4185 - accuracy: 0.8910
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 62 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 102/109 [===========================>..] - ETA: 2:42 - loss: 0.4189 - accuracy: 0.8911
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 6 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 103/109 [===========================>..] - ETA: 2:21 - loss: 0.4192 - accuracy: 0.8905
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 0 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 104/109 [===========================>..] - ETA: 1:59 - loss: 0.4193 - accuracy: 0.8902
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 39 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 105/109 [===========================>..] - ETA: 1:36 - loss: 0.4192 - accuracy: 0.8903
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 40 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 106/109 [============================>.] - ETA: 1:13 - loss: 0.4196 - accuracy: 0.8902
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 67 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 107/109 [============================>.] - ETA: 49s - loss: 0.4192 - accuracy: 0.8906
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 17 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 108/109 [============================>.] - ETA: 24s - loss: 0.4187 - accuracy: 0.8903
# /usr/local/lib/python3.4/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 3 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 109/109 [==============================] - 3367s 31s/step - loss: 0.4183 - accuracy: 0.8905 - val_loss: 0.3880 - val_accuracy: 0.9139
# Epoch 5/30
# 109/109 [==============================] - 2631s 24s/step - loss: 0.3859 - accuracy: 0.8973 - val_loss: 0.3994 - val_accuracy: 0.9069
# Epoch 6/30
# 109/109 [==============================] - 2069s 19s/step - loss: 0.3871 - accuracy: 0.8966 - val_loss: 0.4043 - val_accuracy: 0.9039
# Epoch 7/30
# 109/109 [==============================] - 2032s 19s/step - loss: 0.3748 - accuracy: 0.9011 - val_loss: 0.3957 - val_accuracy: 0.9052
# Epoch 17/30
# 109/109 [==============================] - 2017s 19s/step - loss: 0.3521 - accuracy: 0.9014 - val_loss: 0.3618 - val_accuracy: 0.9122
# Epoch 18/30
# 109/109 [==============================] - 2019s 19s/step - loss: 0.3570 - accuracy: 0.9003 - val_loss: 0.2862 - val_accuracy: 0.9215
# Epoch 19/30
# 109/109 [==============================] - 2018s 19s/step - loss: 0.3376 - accuracy: 0.9040 - val_loss: 0.3118 - val_accuracy: 0.9154
# Epoch 20/30
# 109/109 [==============================] - 2010s 18s/step - loss: 0.3429 - accuracy: 0.9047 - val_loss: 0.3454 - val_accuracy: 0.9051
# Epoch 21/30
# 109/109 [==============================] - 2005s 18s/step - loss: 0.3527 - accuracy: 0.9013 - val_loss: 0.3673 - val_accuracy: 0.8979
# Epoch 22/30
# 109/109 [==============================] - 2004s 18s/step - loss: 0.3269 - accuracy: 0.9052 - val_loss: 0.2807 - val_accuracy: 0.9176
# Epoch 23/30
# 109/109 [==============================] - 2010s 18s/step - loss: 0.3306 - accuracy: 0.9057 - val_loss: 0.3259 - val_accuracy: 0.9229
# Epoch 24/30
# 109/109 [==============================] - 2009s 18s/step - loss: 0.3268 - accuracy: 0.9055 - val_loss: 0.3902 - val_accuracy: 0.9190
# Epoch 25/30
# 109/109 [==============================] - 2007s 18s/step - loss: 0.3342 - accuracy: 0.9027 - val_loss: 0.3185 - val_accuracy: 0.9207
# Epoch 26/30
# 109/109 [==============================] - 2015s 18s/step - loss: 0.3313 - accuracy: 0.9030 - val_loss: 0.4591 - val_accuracy: 0.9032
# Epoch 27/30
# 109/109 [==============================] - 2015s 18s/step - loss: 0.3563 - accuracy: 0.8998 - val_loss: 0.3023 - val_accuracy: 0.9158
# Epoch 28/30
# 109/109 [==============================] - 2014s 18s/step - loss: 0.3314 - accuracy: 0.9049 - val_loss: 0.3447 - val_accuracy: 0.9091
# Epoch 29/30
# 109/109 [==============================] - 2012s 18s/step - loss: 0.3280 - accuracy: 0.9047 - val_loss: 0.2900 - val_accuracy: 0.9173
# Epoch 30/30
# 109/109 [==============================] - 2018s 19s/step - loss: 0.3195 - accuracy: 0.9085 - val_loss: 0.3305 - val_accuracy: 0.9156

# %%
i = 10
url ='https://i.ytimg.com/vi/qLfZHef8oRU/hqdefault.jpg'
img = load_image(url)
img = preprocess(img)
#img = validation_generator[1][0][i]
a = np.expand_dims(img,axis=0)
#b = validation_generator[1][0][i]
b = load_image(url)
certo = validation_generator[1][1][i]

# %%
res = model.predict(a)
#show_im(b)
b.show()

# %%
print(res)
return_class(res[0])
# Out:
# [[0.01375616 0.01863297 0.05064154 0.4491305 ]]
# []

# %%
return_class(certo)
# Out:
# ['emotion_peaceful']

# %%
#model.save('model')

# %%
m#odel.save_weights('weights_emotions.h5')

# %%
for i in train_generator[0][0]:
  print(i.shape)
  plt.imshow(i)
  plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)

# %%
train_generator[0][0][2]
