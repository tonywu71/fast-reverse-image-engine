# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sqlite3 as sql

from urllib.request import urlretrieve # to download images from the web

# %%
def get_link(i,cursor,file_path = 'data.sqlite'):
    cursor.execute('''
            SELECT src FROM MODULES
            INNER JOIN AUTOMATIC_LABELS on MODULES.mid = AUTOMATIC_LABELS.mid
            limit 1 offset ?
            ''',(i,))
    result = cursor.fetchall()
    if(len(result) == 0):
        print("############# MID = ", mid," DOES NOT EXIST #########################")
        return result
    return result[0][0]

def get_mid_i(i,cursor,file_path = 'data.sqlite'):
    cursor.execute('''
            SELECT modules.mid FROM MODULES
            INNER JOIN AUTOMATIC_LABELS on MODULES.mid = AUTOMATIC_LABELS.mid
            limit 1 offset ?
            ''',(i,))
    result = cursor.fetchall()
    if(len(result) == 0):
        print("############# MID = ", mid," DOES NOT EXIST #########################")
        return result
    return result[0][0]

# %%
conn = sql.connect('data.sqlite')
cursor = conn.cursor()
get_mid_i(100,cursor)
get_link(0,cursor)
# Out:
# 'https://mir-s3-cdn-cf.behance.net/project_modules/disp/f8d8ad18589705.562cbfd7658c9.JPG'

# %%
ids_corrompus = []

# %%
i = 15500

while(i<100000):
    url = get_link(i,cursor);
    try:
        urlretrieve(url)
    except:
        ids_corrompus.append(get_mid_i(i,cursor))
    i=i+1
    if(i%100 == 0):
        print(i)
# Out:
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# ...

# %%
ids_corrompus
# Out:
# [16777240,
#  16777240,
#  216705711,
#  44385137,
#  163577903,
#  224022099,
#  48933555,
#  159383615,
#  117440577,
#  113246295,
#  113246303,
#  146800737,
#  105446125,
#  220900029,
#  20530707,
#  171966483,
#  54526069,
#  129324393,
#  213909634,
#  83886227,
#  121634965,
#  92274881,
#  33659187,
#  29360338,
#  100663509,
#  46137573,
#  138412275,
#  148490491,
#  146101635,
#  8388909,
#  159383603,
#  231059695,
#  192938309,
#  102401451,
#  121635165,
#  197831397,
#  104857971,
#  120753273,
#  79692185,
#  57541849,
#  117440923,
#  196656595,
#  104858015,
#  230687137,
#  79692195,
#  4194724,
#  4194725,
#  210322859,
#  210976039,
#  155189713,
#  243270105,
#  138412509,
#  86312769,
#  186452323,
#  138412537,
#  191061257,
#  232674197,
#  192938509,
#  115343449,
#  192457905,
#  146800733,
#  201327163,
#  201327167,
#  201327169,
#  67109449,
#  85983333,
#  222066813,
#  67109491,
#  213910132,
#  134218387,
#  229888035,
#  234881723,
#  238264187,
# ...

# %%
def get_image(mid): ## Gives the image identifier (MID) and returns the link to the image
    # HEADER NEEDED '''...'''
    conn = sql.connect('data.sqlite')
    cursor = conn.cursor()
    cursor.execute('''
                SELECT src FROM MODULES
                INNER JOIN AUTOMATIC_LABELS on MODULES.mid = AUTOMATIC_LABELS.mid
                where MODULES.mid = ?
          ''',(mid,))
    result = cursor.fetchall()
    if(len(result) == 0):
        print("############# MID = ", mid," DOES NOT EXIST #########################")
        return result
    return result[0][0]

# %%
get_image(ids_corrompus[69])
# Out:
# 'https://mir-s3-cdn-cf.behance.net/project_modules/disp/21ece419903123.562e2301ed6d3.jpg'

# %%
for j in ids_corrompus:
    cursor.execute('''
        DELETE from MODULES where MID = ?
    ''', (j,))
    conn.commit()

# %%
cursor.execute('''
        DELETE from MODULES where MID = ?
    ''', (16777240,))
conn.commit()

# %%
get_image(159398999)
# Out:
# ############# MID =  159398999  DOES NOT EXIST #########################
# []
